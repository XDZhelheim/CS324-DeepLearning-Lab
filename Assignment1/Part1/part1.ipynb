# %% [markdown]
# # Task 1: perceptron
#
# 11812804 董正

# %%
from perceptron import Perceptron

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

SEED = 24

# %%
DIM = 2
MAX_EPOCHS = 2000
LR = 0.01
NUM_POINTS = 200

# %% [markdown]
# ## Case 1
#
# Normal case.

# %%
mu1, mu2, sigma1, sigma2 = 0, 10, 4, 4

p = Perceptron(DIM, MAX_EPOCHS, LR)

x, y = p.gen_dataset(NUM_POINTS, mu1, sigma1, mu2, sigma2)
x_train, x_test, y_train, y_test = train_test_split(x,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=SEED)

p.train(x_train, y_train, verbose=100)
# Out:
# Train set shape (320, 2)
# 2022-03-07 21:12:09.610993 Epoch 100 Train Loss = 3.335
# 2022-03-07 21:12:09.793513 Epoch 200 Train Loss = 9.607
# 2022-03-07 21:12:09.920216 Epoch 300 Train Loss = 3.371
# 2022-03-07 21:12:10.065827 Epoch 400 Train Loss = 4.798
# 2022-03-07 21:12:10.186461 Epoch 500 Train Loss = 5.776
# 2022-03-07 21:12:10.300171 Epoch 600 Train Loss = 6.656
# 2022-03-07 21:12:10.426861 Epoch 700 Train Loss = 9.522
# 2022-03-07 21:12:10.536526 Epoch 800 Train Loss = 7.899
# 2022-03-07 21:12:10.647230 Epoch 900 Train Loss = 3.523
# 2022-03-07 21:12:10.760924 Epoch 1000 Train Loss = 3.071
# 2022-03-07 21:12:10.896158 Epoch 1100 Train Loss = 14.945
# 2022-03-07 21:12:11.007858 Epoch 1200 Train Loss = 4.608
# 2022-03-07 21:12:11.124634 Epoch 1300 Train Loss = 4.094
# 2022-03-07 21:12:11.240281 Epoch 1400 Train Loss = 4.333
# 2022-03-07 21:12:11.350538 Epoch 1500 Train Loss = 5.705
# 2022-03-07 21:12:11.474799 Epoch 1600 Train Loss = 27.455
# 2022-03-07 21:12:11.585503 Epoch 1700 Train Loss = 3.981
# 2022-03-07 21:12:11.696206 Epoch 1800 Train Loss = 7.769
# 2022-03-07 21:12:11.816884 Epoch 1900 Train Loss = 7.317
# 2022-03-07 21:12:11.952480 Epoch 2000 Train Loss = 3.726

# %%
y_pred = p.forward(x_test)

print("accuracy = %.3f" % metrics.accuracy_score(y_test, y_pred))
print("precision = %.3f" % metrics.precision_score(y_test, y_pred))
print("recall = %.3f" % metrics.recall_score(y_test, y_pred))
print("f1 = %.3f" % metrics.f1_score(y_test, y_pred))
# Out:
# Test set shape (80, 2)
# accuracy = 0.975
# precision = 0.977
# recall = 0.977
# f1 = 0.977

# %%
points = plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=8, cmap="plasma")
x_plot = np.linspace(-1000, 1000, 100)
y_plot = (-p.w[0] * x_plot - p.b) / p.w[1]
plt.xlim(np.min(x_train[:, 0]) - 0.5, np.max(x_train[:, 0]) + 0.5)
plt.ylim(np.min(x_train[:, 1]) - 0.5, np.max(x_train[:, 1]) + 0.5)
plt.legend(*points.legend_elements())
plt.title("Train")
plt.plot(x_plot, y_plot, c="red")
plt.show();

points = plt.scatter(x_test[:, 0], x_test[:, 1], c=y_test, s=8, cmap="plasma")
x_plot = np.linspace(-1000, 1000, 100)
y_plot = (-p.w[0] * x_plot - p.b) / p.w[1]
plt.xlim(np.min(x_test[:, 0]) - 0.5, np.max(x_test[:, 0]) + 0.5)
plt.ylim(np.min(x_test[:, 1]) - 0.5, np.max(x_test[:, 1]) + 0.5)
plt.legend(*points.legend_elements())
plt.title("Test")
plt.plot(x_plot, y_plot, c="red")
plt.show();

# %% [markdown]
# ## Case 2
#
# The means of the two Gaussians are too close.
#
# Here we set both of their average values as 0.

# %%
mu1, mu2, sigma1, sigma2 = 0, 0, 0.5, 1

p = Perceptron(DIM, MAX_EPOCHS, LR)

x, y = p.gen_dataset(NUM_POINTS, mu1, sigma1, mu2, sigma2)
x_train, x_test, y_train, y_test = train_test_split(x,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=SEED)

p.train(x_train, y_train, verbose=100)
# Out:
# Train set shape (320, 2)
# 2022-03-07 21:12:13.158058 Epoch 100 Train Loss = 2.343
# 2022-03-07 21:12:13.376438 Epoch 200 Train Loss = 1.266
# 2022-03-07 21:12:13.565972 Epoch 300 Train Loss = 2.124
# 2022-03-07 21:12:13.772377 Epoch 400 Train Loss = 2.838
# 2022-03-07 21:12:13.954931 Epoch 500 Train Loss = 1.773
# 2022-03-07 21:12:14.132335 Epoch 600 Train Loss = 1.689
# 2022-03-07 21:12:14.302960 Epoch 700 Train Loss = 1.917
# 2022-03-07 21:12:14.501795 Epoch 800 Train Loss = 1.558
# 2022-03-07 21:12:14.669390 Epoch 900 Train Loss = 1.438
# 2022-03-07 21:12:14.850863 Epoch 1000 Train Loss = 1.813
# 2022-03-07 21:12:15.032417 Epoch 1100 Train Loss = 3.639
# 2022-03-07 21:12:15.217906 Epoch 1200 Train Loss = 3.099
# 2022-03-07 21:12:15.380486 Epoch 1300 Train Loss = 1.711
# 2022-03-07 21:12:15.553109 Epoch 1400 Train Loss = 0.917
# 2022-03-07 21:12:15.729642 Epoch 1500 Train Loss = 2.816
# 2022-03-07 21:12:15.961067 Epoch 1600 Train Loss = 2.137
# 2022-03-07 21:12:16.136189 Epoch 1700 Train Loss = 3.359
# 2022-03-07 21:12:16.318658 Epoch 1800 Train Loss = 1.291
# 2022-03-07 21:12:16.535080 Epoch 1900 Train Loss = 0.425
# 2022-03-07 21:12:16.736540 Epoch 2000 Train Loss = 2.506

# %%
y_pred = p.forward(x_test)

print("accuracy = %.3f" % metrics.accuracy_score(y_test, y_pred))
print("precision = %.3f" % metrics.precision_score(y_test, y_pred))
print("recall = %.3f" % metrics.recall_score(y_test, y_pred))
print("f1 = %.3f" % metrics.f1_score(y_test, y_pred))
# Out:
# Test set shape (80, 2)
# accuracy = 0.537
# precision = 0.590
# recall = 0.523
# f1 = 0.554

# %% [markdown]
# Accuracy is around 0.5.
#
# From the figure below we can see that the perceptron cannot classify them well because their average are too close, probably any line that passes $(0, 0)$ can acheive 0.5 accuracy.

# %%
points = plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=8, cmap="plasma")
x_plot = np.linspace(-1000, 1000, 100)
y_plot = (-p.w[0] * x_plot - p.b) / p.w[1]
plt.xlim(np.min(x_train[:, 0]) - 0.5, np.max(x_train[:, 0]) + 0.5)
plt.ylim(np.min(x_train[:, 1]) - 0.5, np.max(x_train[:, 1]) + 0.5)
plt.legend(*points.legend_elements())
plt.title("Train")
plt.plot(x_plot, y_plot, c="red")
plt.show();

points = plt.scatter(x_test[:, 0], x_test[:, 1], c=y_test, s=8, cmap="plasma")
x_plot = np.linspace(-1000, 1000, 100)
y_plot = (-p.w[0] * x_plot - p.b) / p.w[1]
plt.xlim(np.min(x_test[:, 0]) - 0.5, np.max(x_test[:, 0]) + 0.5)
plt.ylim(np.min(x_test[:, 1]) - 0.5, np.max(x_test[:, 1]) + 0.5)
plt.legend(*points.legend_elements())
plt.title("Test")
plt.plot(x_plot, y_plot, c="red")
plt.show();

# %% [markdown]
# ## Case 3
#
# Variance is too high.

# %%
mu1, mu2, sigma1, sigma2 = 0, 10, 20, 20

p = Perceptron(DIM, MAX_EPOCHS, LR)

x, y = p.gen_dataset(NUM_POINTS, mu1, sigma1, mu2, sigma2)
x_train, x_test, y_train, y_test = train_test_split(x,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=SEED)

p.train(x_train, y_train, verbose=100)
# Out:
# Train set shape (320, 2)
# 2022-03-07 21:12:17.685953 Epoch 100 Train Loss = 823.555
# 2022-03-07 21:12:17.890712 Epoch 200 Train Loss = 730.957
# 2022-03-07 21:12:18.075261 Epoch 300 Train Loss = 650.978
# 2022-03-07 21:12:18.257735 Epoch 400 Train Loss = 300.642
# 2022-03-07 21:12:18.459191 Epoch 500 Train Loss = 125.964
# 2022-03-07 21:12:18.664642 Epoch 600 Train Loss = 203.307
# 2022-03-07 21:12:18.879638 Epoch 700 Train Loss = 253.047
# 2022-03-07 21:12:19.069131 Epoch 800 Train Loss = 587.751
# 2022-03-07 21:12:19.263167 Epoch 900 Train Loss = 1529.335
# 2022-03-07 21:12:19.443193 Epoch 1000 Train Loss = 672.661
# 2022-03-07 21:12:19.647660 Epoch 1100 Train Loss = 1740.940
# 2022-03-07 21:12:19.843128 Epoch 1200 Train Loss = 941.983
# 2022-03-07 21:12:20.014623 Epoch 1300 Train Loss = 229.993
# 2022-03-07 21:12:20.189154 Epoch 1400 Train Loss = 1008.955
# 2022-03-07 21:12:20.384631 Epoch 1500 Train Loss = 293.299
# 2022-03-07 21:12:20.557216 Epoch 1600 Train Loss = 1005.865
# 2022-03-07 21:12:20.730166 Epoch 1700 Train Loss = 703.771
# 2022-03-07 21:12:20.900751 Epoch 1800 Train Loss = 947.574
# 2022-03-07 21:12:21.116177 Epoch 1900 Train Loss = 648.009
# 2022-03-07 21:12:21.296693 Epoch 2000 Train Loss = 380.703

# %%
y_pred = p.forward(x_test)

print("accuracy = %.3f" % metrics.accuracy_score(y_test, y_pred))
print("precision = %.3f" % metrics.precision_score(y_test, y_pred))
print("recall = %.3f" % metrics.recall_score(y_test, y_pred))
print("f1 = %.3f" % metrics.f1_score(y_test, y_pred))
# Out:
# Test set shape (80, 2)
# accuracy = 0.613
# precision = 0.686
# recall = 0.545
# f1 = 0.608

# %% [markdown]
# Because the variance is high, all the points are mixed together. Therefore, they are unclassifiable, which is similar to Case 2.

# %%
points = plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=8, cmap="plasma")
x_plot = np.linspace(-1000, 1000, 100)
y_plot = (-p.w[0] * x_plot - p.b) / p.w[1]
plt.xlim(np.min(x_train[:, 0]) - 0.5, np.max(x_train[:, 0]) + 0.5)
plt.ylim(np.min(x_train[:, 1]) - 0.5, np.max(x_train[:, 1]) + 0.5)
plt.legend(*points.legend_elements())
plt.title("Train")
plt.plot(x_plot, y_plot, c="red")
plt.show();

points = plt.scatter(x_test[:, 0], x_test[:, 1], c=y_test, s=8, cmap="plasma")
x_plot = np.linspace(-1000, 1000, 100)
y_plot = (-p.w[0] * x_plot - p.b) / p.w[1]
plt.xlim(np.min(x_test[:, 0]) - 0.5, np.max(x_test[:, 0]) + 0.5)
plt.ylim(np.min(x_test[:, 1]) - 0.5, np.max(x_test[:, 1]) + 0.5)
plt.legend(*points.legend_elements())
plt.title("Test")
plt.plot(x_plot, y_plot, c="red")
plt.show();
