# %% [markdown]
# # Part 3: RNN
#
# 11812804 董正

# %% [markdown]
# ## Task 1: Implementation
#
# See [vanilla_rnn.py](vanilla_rnn.py) and [train.py](train.py).

# %%
# %run train.py -h
# Out:
# usage: train.py [-h] [--input_length INPUT_LENGTH] [--input_dim INPUT_DIM]
#                 [--num_classes NUM_CLASSES] [--num_hidden NUM_HIDDEN]
#                 [--learning_rate LEARNING_RATE] [--batch_size BATCH_SIZE]
#                 [--max_epochs MAX_EPOCHS] [--max_norm MAX_NORM]
#                 [--eval_freq EVAL_FREQ] [--num_workers NUM_WORKERS]
#                 [--visual_model] [--quiet] [--gpu]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --input_length INPUT_LENGTH
#                         Length of an input sequence
#   --input_dim INPUT_DIM
#                         Dimensionality of input sequence
#   --num_classes NUM_CLASSES
#                         Dimensionality of output sequence
#   --num_hidden NUM_HIDDEN
#                         Number of hidden units in the model
#   --learning_rate LEARNING_RATE, -l LEARNING_RATE
#                         Learning rate.
#   --batch_size BATCH_SIZE, -b BATCH_SIZE
#                         Batch size
#   --max_epochs MAX_EPOCHS, -e MAX_EPOCHS
#                         Number of epochs to run trainer.
#   --max_norm MAX_NORM
#   --eval_freq EVAL_FREQ, -f EVAL_FREQ
#                         Frequency of evaluation on the test set.
#   --num_workers NUM_WORKERS, -w NUM_WORKERS
#                         Param num_workers of pytorch. Set to 0 when using
#                         Jupyter!!!
#   --visual_model, -v    Visualize model after training.
#   --quiet, -q           No stdout when training.
#   --gpu, -g             Use GPU.

# %%
# %run train.py -s 1000 -f 20 -v -b 128 --input_length 5
# Out:
# ---Using CPU---
# 2022-04-16 14:43:49.828327 Step 20 	Train Loss = 2.22022 Train acc = 0.215  Eval Loss = 2.16642 Eval acc = 0.298
# 2022-04-16 14:43:50.058711 Step 40 	Train Loss = 2.11709 Train acc = 0.344  Eval Loss = 2.05862 Eval acc = 0.409
# 2022-04-16 14:43:50.309043 Step 60 	Train Loss = 2.03708 Train acc = 0.448  Eval Loss = 1.99619 Eval acc = 0.525
# 2022-04-16 14:43:50.554386 Step 80 	Train Loss = 1.98799 Train acc = 0.520  Eval Loss = 1.99381 Eval acc = 0.472
# 2022-04-16 14:43:50.892482 Step 100 	Train Loss = 1.92777 Train acc = 0.564  Eval Loss = 1.87887 Eval acc = 0.617
# 2022-04-16 14:43:51.133837 Step 120 	Train Loss = 1.89273 Train acc = 0.595  Eval Loss = 1.90026 Eval acc = 0.584
# 2022-04-16 14:43:51.359234 Step 140 	Train Loss = 1.86881 Train acc = 0.613  Eval Loss = 1.89138 Eval acc = 0.567
# 2022-04-16 14:43:51.642477 Step 160 	Train Loss = 1.84261 Train acc = 0.637  Eval Loss = 1.84615 Eval acc = 0.666
# 2022-04-16 14:43:51.990546 Step 180 	Train Loss = 1.82407 Train acc = 0.664  Eval Loss = 1.81194 Eval acc = 0.613
# 2022-04-16 14:43:57.653404 Step 620 	Train Loss = 1.61718 Train acc = 0.868  Eval Loss = 1.57778 Eval acc = 0.905
# 2022-04-16 14:43:57.882791 Step 640 	Train Loss = 1.57602 Train acc = 0.904  Eval Loss = 1.57969 Eval acc = 0.897
# 2022-04-16 14:43:58.157058 Step 660 	Train Loss = 1.57482 Train acc = 0.902  Eval Loss = 1.57510 Eval acc = 0.898
# 2022-04-16 14:43:58.366500 Step 680 	Train Loss = 1.57652 Train acc = 0.896  Eval Loss = 1.55915 Eval acc = 0.914
# 2022-04-16 14:43:58.579969 Step 700 	Train Loss = 1.56171 Train acc = 0.910  Eval Loss = 1.57519 Eval acc = 0.895
# 2022-04-16 14:43:58.758449 Step 720 	Train Loss = 1.56288 Train acc = 0.907  Eval Loss = 1.58105 Eval acc = 0.886
# 2022-04-16 14:43:58.962903 Step 740 	Train Loss = 1.57839 Train acc = 0.889  Eval Loss = 1.57143 Eval acc = 0.895
# 2022-04-16 14:43:59.157382 Step 760 	Train Loss = 1.57547 Train acc = 0.891  Eval Loss = 1.55878 Eval acc = 0.908
# 2022-04-16 14:43:59.350866 Step 780 	Train Loss = 1.56142 Train acc = 0.904  Eval Loss = 1.56282 Eval acc = 0.902
# 2022-04-16 14:43:59.561303 Step 800 	Train Loss = 1.56128 Train acc = 0.903  Eval Loss = 1.58602 Eval acc = 0.877
# 2022-04-16 14:43:59.734839 Step 820 	Train Loss = 1.55805 Train acc = 0.905  Eval Loss = 1.56947 Eval acc = 0.894
# 2022-04-16 14:44:00.049996 Step 840 	Train Loss = 1.55241 Train acc = 0.911  Eval Loss = 1.56667 Eval acc = 0.895
# 2022-04-16 14:44:00.310300 Step 860 	Train Loss = 1.57228 Train acc = 0.890  Eval Loss = 1.55151 Eval acc = 0.911
# 2022-04-16 14:44:00.630445 Step 880 	Train Loss = 1.56677 Train acc = 0.895  Eval Loss = 1.56439 Eval acc = 0.897
# 2022-04-16 14:44:00.856839 Step 900 	Train Loss = 1.56428 Train acc = 0.897  Eval Loss = 1.56226 Eval acc = 0.898
# 2022-04-16 14:44:01.080242 Step 920 	Train Loss = 1.56437 Train acc = 0.896  Eval Loss = 1.56904 Eval acc = 0.892
# 2022-04-16 14:44:01.352515 Step 940 	Train Loss = 1.55755 Train acc = 0.903  Eval Loss = 1.56481 Eval acc = 0.895
# 2022-04-16 14:44:01.640745 Step 960 	Train Loss = 1.56103 Train acc = 0.900  Eval Loss = 1.57665 Eval acc = 0.883
# 2022-04-16 14:44:01.900051 Step 980 	Train Loss = 1.56460 Train acc = 0.895  Eval Loss = 1.55508 Eval acc = 0.905
# 2022-04-16 14:44:02.115474 Step 1000 	Train Loss = 1.55740 Train acc = 0.902  Eval Loss = 1.55108 Eval acc = 0.909
