# %%
# %run my_gan.py -e 10 -f 1 -v -s 1 -b 128
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# h:\Codes\PythonWorkspace\CS324-DeepLearning-Lab\Assignment3\Part 2\my_gan.py in <module>
#     397     args = parser.parse_args()
#     398
# --> 399     main(args)
#
# h:\Codes\PythonWorkspace\CS324-DeepLearning-Lab\Assignment3\Part 2\my_gan.py in main(args)
#     322
#     323     # Start training
# --> 324     train(
#     325         dataloader,
#     326         discriminator,
#
# h:\Codes\PythonWorkspace\CS324-DeepLearning-Lab\Assignment3\Part 2\my_gan.py in train(dataloader, discriminator, generator, optimizer_G, optimizer_D, noise_dim, batch_size, max_epochs, verbose, save_interval, visual_model, quiet)
#     220
#     221             optimizer_D.zero_grad()
# --> 222             D_loss.backward()
#     223             optimizer_D.step()
#     224
#
# ...
