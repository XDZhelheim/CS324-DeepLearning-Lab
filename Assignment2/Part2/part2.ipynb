# %% [markdown]
# # Part 2: CNN
#
# 11812804 董正

# %% [markdown]
# ## Task 1: Implementation
#
# See [cnn_model.py](cnn_model.py) and [cnn_train.py](cnn_train.py).

# %%
# %run cnn_train.py -h
# Out:
# usage: cnn_train.py [-h] [--data_dir DATA_DIR] [--learning_rate LEARNING_RATE]
#                     [--batch_size BATCH_SIZE] [--max_epochs MAX_EPOCHS]
#                     [--eval_freq EVAL_FREQ] [--num_workers NUM_WORKERS]
#                     [--visual_model] [--quiet] [--gpu]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --data_dir DATA_DIR, -d DATA_DIR
#                         Directory for storing input data
#   --learning_rate LEARNING_RATE, -l LEARNING_RATE
#                         Learning rate.
#   --batch_size BATCH_SIZE, -b BATCH_SIZE
#                         Batch size
#   --max_epochs MAX_EPOCHS, -e MAX_EPOCHS
#                         Number of epochs to run trainer.
#   --eval_freq EVAL_FREQ, -f EVAL_FREQ
#                         Frequency of evaluation on the test set.
#   --num_workers NUM_WORKERS, -w NUM_WORKERS
#                         Param num_workers of pytorch. Set to 0 when using
# ...

# %% [markdown]
# ## Task 2: Performance on CIFAR10

# %%
# %run cnn_train.py -e 30 -f 1 -v --gpu
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ---Using CUDA---
# Train set shape (50000, 32, 32, 3)
# Num of batches = 781
# 2022-04-13 11:26:44.926040 Epoch 1 	Train Loss = 1.94367 Train acc = 0.517  Eval Loss = 1.84873 Eval acc = 0.610
# 2022-04-13 11:27:23.855305 Epoch 2 	Train Loss = 1.81687 Train acc = 0.644  Eval Loss = 1.80047 Eval acc = 0.661
# 2022-04-13 11:28:04.085001 Epoch 3 	Train Loss = 1.76031 Train acc = 0.699  Eval Loss = 1.75147 Eval acc = 0.711
# 2022-04-13 11:28:44.229319 Epoch 4 	Train Loss = 1.72951 Train acc = 0.731  Eval Loss = 1.73569 Eval acc = 0.724
# 2022-04-13 11:29:24.586631 Epoch 5 	Train Loss = 1.70039 Train acc = 0.761  Eval Loss = 1.71563 Eval acc = 0.744
# 2022-04-13 11:30:04.947082 Epoch 6 	Train Loss = 1.67876 Train acc = 0.783  Eval Loss = 1.71440 Eval acc = 0.745
# 2022-04-13 11:30:46.239684 Epoch 7 	Train Loss = 1.66470 Train acc = 0.797  Eval Loss = 1.69344 Eval acc = 0.767
# ...

# %%
# %run cnn_train.py -e 50 -f 1 -v --gpu
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ---Using CUDA---
# Train set shape (50000, 32, 32, 3)
# Num of batches = 781
# 2022-04-16 19:45:45.319883 Epoch 1 	Train Loss = 1.96470 Train acc = 0.493  Eval Loss = 1.88361 Eval acc = 0.576
# 2022-04-16 19:46:20.428010 Epoch 2 	Train Loss = 1.83378 Train acc = 0.626  Eval Loss = 1.80626 Eval acc = 0.652
# 2022-04-16 19:46:56.421028 Epoch 3 	Train Loss = 1.77391 Train acc = 0.686  Eval Loss = 1.77181 Eval acc = 0.688
# 2022-04-16 19:47:31.907879 Epoch 4 	Train Loss = 1.73827 Train acc = 0.722  Eval Loss = 1.75197 Eval acc = 0.708
# 2022-04-16 19:48:07.682561 Epoch 5 	Train Loss = 1.70849 Train acc = 0.752  Eval Loss = 1.72629 Eval acc = 0.735
# 2022-04-16 19:48:44.266889 Epoch 6 	Train Loss = 1.68833 Train acc = 0.773  Eval Loss = 1.72201 Eval acc = 0.740
# 2022-04-16 19:49:20.731483 Epoch 7 	Train Loss = 1.66809 Train acc = 0.793  Eval Loss = 1.71479 Eval acc = 0.746
# ...

# %% [markdown]
# Training this CNN network is very time-costing with my GPU. We can see that it achieved 83% accuracy on test set after 50 epochs.
#
# The training loss is still dropping rapidly but the test accuracy is hardly growing, maybe it is overfitting.
